# %% [markdown]
# <a href="https://colab.research.google.com/github/timayez/UCDPA_Ayomide/blob/main/Loan_project_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Loan-test project

# %% [markdown]
# Importing data

# %%
import pandas as pd

# %% [markdown]
# Reading 'loan-test' csv file

# %%
loan = pd.read_csv('loan-test.csv') 
loan
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %% [markdown]
# Getting the first 10 colums on 'loan data'

# %%
loan.head(10)
# Out:
#     Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP001015    Male     Yes          0      Graduate            No
# 1  LP001022    Male     Yes          1      Graduate            No
# 2  LP001031    Male     Yes          2      Graduate            No
# 3  LP001035    Male     Yes          2      Graduate            No
# 4  LP001051    Male      No          0  Not Graduate            No
# 5  LP001054    Male     Yes          0  Not Graduate           Yes
# 6  LP001055  Female      No          1  Not Graduate            No
# 7  LP001056    Male     Yes          2  Not Graduate            No
# 8  LP001059    Male     Yes          2      Graduate           NaN
# 9  LP001067    Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# ...

# %% [markdown]
# Getting last 10 colums on 'loan data'

# %%
loan.tail(5)
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 362             4009               1777       113.0             360.0
# 363             4158                709       115.0             360.0
# 364             3250               1993       126.0             360.0
# 365             5000               2393       158.0             360.0
# 366             9200                  0        98.0             180.0
#
#      Credit_History Property_Area
# 362             1.0         Urban
# 363             1.0         Urban
# ...

# %% [markdown]
# Describing 'Loan'

# %%
loan.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       367.000000         367.000000  362.000000        361.000000
# mean       4805.599455        1569.577657  136.132597        342.537396
# std        4910.685399        2334.232099   61.366652         65.156643
# min           0.000000           0.000000   28.000000          6.000000
# 25%        2864.000000           0.000000  100.250000        360.000000
# 50%        3786.000000        1025.000000  125.000000        360.000000
# 75%        5060.000000        2430.500000  158.000000        360.000000
# max       72529.000000       24000.000000  550.000000        480.000000
#
#        Credit_History
# count      338.000000
# mean         0.825444
# std          0.380150
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %% [markdown]
# Getting information of 'loan'

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            367 non-null    object
#  1   Gender             356 non-null    object
#  2   Married            367 non-null    object
#  3   Dependents         357 non-null    object
#  4   Education          367 non-null    object
#  5   Self_Employed      344 non-null    object
#  6   ApplicantIncome    367 non-null    int64
#  7   CoapplicantIncome  367 non-null    int64
#  8   LoanAmount         362 non-null    float64
#  9   Loan_Amount_Term   361 non-null    float64
#  10  Credit_History     338 non-null    float64
#  11  Property_Area      367 non-null    object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 34.5+ KB

# %% [markdown]
# loan.info()
# Info shows that there are 367 Rows and 12 columns
#
# Gender has 11 rows without entry null value(NV)
#
# Dependant: has 12 Nv
#
# self_employed: has 23 NV
#
# Loan_Amount: 5 NV
#
#  Loan_Amount_Term: 6 NV
#
# Credit_History: 29 NV

# %% [markdown]
# Creating Dataframe

# %%
pd.DataFrame(loan)
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %% [markdown]
# Data Clenaing

# %%
# Removing Null-Values, and assinging new dataframe to variable 'new-loan'
new_loan = loan.dropna()
print(new_loan.to_string())
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History Property_Area
# 0    LP001015    Male     Yes          0      Graduate            No             5720                  0       110.0             360.0             1.0         Urban
# 1    LP001022    Male     Yes          1      Graduate            No             3076               1500       126.0             360.0             1.0         Urban
# 2    LP001031    Male     Yes          2      Graduate            No             5000               1800       208.0             360.0             1.0         Urban
# 4    LP001051    Male      No          0  Not Graduate            No             3276                  0        78.0             360.0             1.0         Urban
# ...

# %% [markdown]
# Now we hope to have a new dataframe with no empty rows. Lets check that.

# %%
new_loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 289 entries, 0 to 366
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            289 non-null    object
#  1   Gender             289 non-null    object
#  2   Married            289 non-null    object
#  3   Dependents         289 non-null    object
#  4   Education          289 non-null    object
#  5   Self_Employed      289 non-null    object
#  6   ApplicantIncome    289 non-null    int64
#  7   CoapplicantIncome  289 non-null    int64
#  8   LoanAmount         289 non-null    float64
#  9   Loan_Amount_Term   289 non-null    float64
#  10  Credit_History     289 non-null    float64
#  11  Property_Area      289 non-null    object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 29.4+ KB

# %% [markdown]
# 79 empty rows intotal have been deleted from previous 'loan' dataframe. Now we have a new dataframe 'new_loan' with 289 rows & 12 columns.
#
# Now the empty values are cleaned out!
